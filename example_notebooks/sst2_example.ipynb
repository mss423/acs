# %% [markdown]
# # SST2 Downsampling & Training Example
#
# This notebook demonstrates how to use the repository's scripts to:
# 1. Load the SST2 dataset.
# 2. Apply various downsampling methods (Random, K-Means, Deduplication).
# 3. Train a BERT model on the downsampled data.
# 4. Compare performance.

# %%
# Install dependencies if not already installed
# !pip install simpletransformers==0.70.1 transformers==4.42.4 pandas numpy scikit-learn torch

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pandas as pd
import numpy as np
from IPython.display import clear_output

user = "mss423"
repo = "acs"

if os.path.isdir(repo):
  # !rm -rf {repo}

# !git clone https://github.com/{user}/{repo}.git

for dirpath, dirnames, filenames in os.walk("acs"):
  sys.path.append(dirpath)

# Add src to path
project_root = os.path.abspath(os.path.join(os.getcwd(), 'acs'))
src_path = os.path.join(project_root, 'src')

if src_path not in sys.path:
    sys.path.append(src_path)

print(f"Added {src_path} to sys.path")

# Import project modules
from data_loader import Dataset
from train import train
from downsampling import apply_downsampling
import config

# %%
# --- Configuration ---
# Point to the raw data directory
config.DATASET_NAME = 'sst2'
config.DATASET_CONFIG = {
    'train_path': os.path.join(project_root, 'data/raw/sst2'),
    'test_path': os.path.join(project_root, 'data/raw/sst2')
}

# Model Args (faster training for demo)
config.MODEL_ARGS['num_train_epochs'] = 1 # Increase for real results
config.MODEL_ARGS['evaluate_during_training'] = False
config.MODEL_ARGS['overwrite_output_dir'] = True
config.MODEL_ARGS['use_multiprocessing'] = False # Sometimes safer in notebooks
config.MODEL_ARGS['use_multiprocessing_for_evaluation'] = False

# %%
# --- Load Data ---
dataset = Dataset(name='sst2', config=config.DATASET_CONFIG)
if not dataset.load():
    raise RuntimeError("Failed to load dataset")

train_df = dataset.train_df
test_df = dataset.test_df
num_labels = dataset.num_labels

print(f"Original Training Data: {len(train_df)} samples")
print(f"Test Data: {len(test_df)} samples")
print(f"Labels: {num_labels}")
train_df.head()

# %% [markdown]
# ## Downsampling Demo
# Let's test the downsampling methods.

# %%
k = 20
methods = ['random', 'kmeans', 'dedup']

for method in methods:
    print(f"\n--- Method: {method} (k={k}) ---")
    try:
        sample = apply_downsampling(
            data=train_df,
            method=method,
            target_size=k,
            random_seed=42,
            label_col='label'
        )
        print(sample.head())
    except Exception as e:
        print(f"Error: {e}")

# %% [markdown]
# ## Experiment Loop
# Run training for different K values and methods.

# %%
def run_experiment(method, k_samples, train_df, test_df, num_labels, reps=1):
    results = []
    for i in range(reps):
        print(f"\n=== Rep {i+1}/{reps} | Method: {method} | K: {k_samples} ===")
        seed = 42 * (i + 1)
        
        # 1. Downsample
        try:
            downsampled_df = apply_downsampling(
                data=train_df,
                method=method,
                target_size=k_samples,
                random_seed=seed,
                label_col='label'
            )
        except Exception as e:
            print(f"Downsampling failed: {e}")
            continue
        
        # 2. Train
        # Unique output dir to avoid conflicts
        output_dir = os.path.join(project_root, f'results/sst2_nb/{method}_{k_samples}_{seed}')
        config.MODEL_ARGS['output_dir'] = output_dir
        
        # Train returns evaluation results on eval_df if provided
        result = train(
            train_df=downsampled_df,
            num_labels=num_labels,
            eval_df=test_df,
            manual_seed=seed,
            num_train_epochs=1 # Keep low for demo
        )
        
        if result:
            # Result is a dict from simpletransformers eval_model
            # e.g., {'mcc': 0.0, 'tp': 0, 'tn': 872, 'fp': 0, 'fn': 949, 'auroc': 0.5, 'auprc': 0.52, 'eval_loss': 0.69}
            # We might want to calculate Accuracy if not present
            # simpletransformers usually returns raw counts. 
            # Let's compute accuracy manually if needed or trust 'mcc'/'eval_loss'
            # Actually, train() in src/train.py prints result but returns it too.
            
            # Add metadata
            res_entry = result.copy()
            res_entry['method'] = method
            res_entry['k'] = k_samples
            res_entry['rep'] = i
            results.append(res_entry)
        
    return pd.DataFrame(results)

# %%
# --- Run Experiments ---
k_values = [10, 50] # Small K for demo
methods = ['random', 'kmeans', 'dedup']

all_results = []

for k in k_values:
    for method in methods:
        df_res = run_experiment(method, k, train_df, test_df, num_labels, reps=1)
        all_results.append(df_res)

if all_results:
    final_results = pd.concat(all_results, ignore_index=True)
    print("\n--- Final Results ---")
    print(final_results[['method', 'k', 'rep', 'eval_loss', 'mcc']]) # Display key metrics
else:
    print("No results generated.")
